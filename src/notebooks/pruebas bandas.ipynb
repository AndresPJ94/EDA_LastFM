# %%
import pandas as pd 
import numpy as np

#LIBRERÍAS DE MATPLOTLIB
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn-colorblind")


#LIBRERIAS DE PLOTLY
from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
from wordcloud import WordCloud
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("200.txt")
df.columns=['banda', 'genero1', 'genero2', 'genero3', 'genero4', 'genero5', 'genero6']
a = df['genero1'].append(df['genero2']).reset_index(drop=True).append(df['genero3']).reset_index(drop=True).append(df['genero4']).reset_index(drop=True).append(df['genero5']).reset_index(drop=True).append(df['genero6']).reset_index(drop=True)
w = a.dropna().value_counts().head(10).to_frame()
w

def func(pct):
 return "{:1.1f}%".format(pct)
plot = w.plot.pie(subplots=True, legend=False, autopct=lambda pct: func(pct))
plt.axis('off')
plt.show()

# %%
df = pd.read_csv("200.txt")
df = df.head(50)
df.columns=['banda', 'genero1', 'genero2', 'genero3', 'genero4', 'genero5', 'genero6']
a = df['genero1'].append(df['genero2']).reset_index(drop=True).append(df['genero3']).reset_index(drop=True).append(df['genero4']).reset_index(drop=True).append(df['genero5']).reset_index(drop=True).append(df['genero6']).reset_index(drop=True)
data = a.dropna().value_counts().head(10)
pd.DataFrame(data)

my_circle=plt.Circle( (0,0), 0.7, color='white')

plt.figure(figsize=(7,7))
plt.pie(data.values,
        labels=data.index,
        autopct='%1.2f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
p.savefig('outputs/corona50.png')

# %%
import matplotlib.pyplot as plt
raw = a.dropna().value_counts().head(10)
# create data
data = raw
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')

plt.figure(figsize=(7,7))
plt.pie(data.values,
        labels=data.index,
        autopct='%1.2f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
p.savefig('outputs/corona200.png')

# %%
# data prepararion
a = df['genero1'].append(df['genero2']).reset_index(drop=True).append(df['genero3']).reset_index(drop=True).append(df['genero4']).reset_index(drop=True).append(df['genero5']).reset_index(drop=True).append(df['genero6']).reset_index(drop=True)
w = a.dropna()
plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                          background_color='white',
                          width=512,
                          height=384
                         ).generate(" ".join(w))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('graph.jpg')
